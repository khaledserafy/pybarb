# %% [markdown]
# # Querying the Barb API using R
#
# In this demo we will show you how to query the Barb API using R. We will do this first without making use of the baRb package (as you may wish to develop your own software from scratch). We will then show you how to use the baRb package to make the same query.
#
# Note the full API documentation can be found [here](https://barb-api.co.uk/api-docs).
#
# It might also be useful to consult the [Getting Started](https://barb-api.co.uk/api-docs#section/Getting-started) section for information about authentication and basic API usage.

# %% [markdown]
# ## Querying the API without baRb
#
# First we use the code and instructions from the notebook "Connecting to the BARB API using R" to connect to the API.

# %%
library(tidyr)
library(jsonlite)

# Set the working directory
working_directory <- '/Users/simon_business/Documents/disposable/clients/BARB/'

# Read the json file containing the credentials
creds <- fromJSON(paste0(working_directory, "creds.json"))

# Get the token
token <- httr::POST(
url = "https://barb-api.co.uk/api/v1/auth/token/",
body = toJSON(creds, auto_unbox=TRUE),
httr::content_type("application/json")
)

# %%
params <- list(
      "min_transmission_date" = "2022-12-25",
      "max_transmission_date" = "2022-12-31",
      "station_code" = 10,
      "panel_code" = 50,
      "limit" = "5000",
      "consolidated" = TRUE
    )

# %% [markdown]
# ### Using the access token to query the API
#
# Let's make a very simple call to the API to demonstrate that the access token works. We'll use the `get` method from the `requests` library to make a `GET` request to the `barb-api.co.uk/api/v1/panels` endpoint. We'll pass the access token as a parameter in the request.

# %%
response <- httr::GET(url = "https://barb-api.co.uk/api/v1/programme_ratings/",
                    httr::add_headers(Authorization = paste0('Bearer ',
                                                                httr::content(token, as = "parsed")$access)),
                    query = params)

raw_json <- response %>%
httr::content()

# %%
raw_json$events[[1]]
# Out:
# $panel
# $panel$panel_code
# [1] 50
#
# $panel$panel_region
# [1] "BBC Network"
#
# $panel$is_macro_region
# [1] FALSE
#
#
# $station
# $station$station_code
# [1] 10
#
# $station$station_name
# [1] "BBC1"
#
#
# $transmission_log_programme_name
# [1] "MICHAEL MCINTYRE'S CHRISTMAS WHEEL"
#
# $programme_type
# [1] "programme"
#
# $programme_start_datetime
# $programme_start_datetime$barb_reporting_datetime
# [1] "2022-12-25 18:25:43"
#
# $programme_start_datetime$barb_polling_datetime
# [1] "2022-12-25 18:25:43"
#
# $programme_start_datetime$standard_datetime
# [1] "2022-12-25 18:25:43"
#
#
# $programme_duration
# [1] 57
#
# $spans_normal_day
# [1] FALSE
#
# $sponsor
# $sponsor$sponsor_code
# NULL
#
# $sponsor$bumpers
# [1] "not_sponsored"
#
#
# $broadcaster_transmission_code
# [1] "15056800065812"
#
# $live_status
# [1] "unknown"
#
# $uk_premier
# [1] TRUE
#
# $broadcaster_premier
# [1] TRUE
#
# $`repeat`
# [1] FALSE
#
# $programme_content
# $programme_content$content_name
# [1] "Michael McIntyre's The Wheel: Series 3, Episode 7"
#
# $programme_content$barb_content_id
# [1] 7398800
#
# $programme_content$broadcaster_content_id
# [1] "m001gnjd"
#
# $programme_content$metabroadcast_information
# $programme_content$metabroadcast_information$metabroadcast_content_id
# [1] "p9jg8r"
#
#
# $programme_content$episode
# $programme_content$episode$episode_number
# [1] 7
#
# $programme_content$episode$episode_name
# [1] "Christmas Special"
#
#
# $programme_content$series
# $programme_content$series$series_number
# [1] "3"
#
# $programme_content$series$number_of_episodes
# [1] 12
#
# $programme_content$series$broadcaster_series_id
# NULL
#
#
# $programme_content$genre
# [1] "Entertainment"
#
#
# $platforms
# $platforms[[1]]
# [1] "Analogue Terrestrial"
#
# $platforms[[2]]
# [1] "Digital Terrestrial"
#
# $platforms[[3]]
# [1] "Analogue Satellite"
#
# $platforms[[4]]
# [1] "Digital Satellite"
#
# $platforms[[5]]
# [1] "Analogue Cable"
#
# $platforms[[6]]
# [1] "Digital Cable"
#
# $platforms[[7]]
# [1] "Online via TV"
#
#
# $audience_views
# $audience_views[[1]]
# $audience_views[[1]]$audience_code
# [1] "200001_202212_50"
#
# $audience_views[[1]]$audience_size_hundreds
# [1] 28849
#
# $audience_views[[1]]$category_id
# [1] 1
#
# $audience_views[[1]]$description
# [1] "All Homes"
#
# $audience_views[[1]]$target_size_in_hundreds
# [1] 272070
#
#
# $audience_views[[2]]
# $audience_views[[2]]$audience_code
# [1] "203002_202212_50"
#
# $audience_views[[2]]$audience_size_hundreds
# [1] 55235
#
# $audience_views[[2]]$category_id
# [1] 2
#
# $audience_views[[2]]$description
# [1] "All Adults"
#
# $audience_views[[2]]$target_size_in_hundreds
# [1] 514750
#
#
# $audience_views[[3]]
# $audience_views[[3]]$audience_code
# [1] "211001_202212_50"
#
# $audience_views[[3]]$audience_size_hundreds
# [1] 21919
#
# $audience_views[[3]]$category_id
# [1] 3
#
# $audience_views[[3]]$description
# [1] "All Men"
#
# $audience_views[[3]]$target_size_in_hundreds
# [1] 250780
#
#
# $audience_views[[4]]
# $audience_views[[4]]$audience_code
# [1] "208001_202212_50"
#
# $audience_views[[4]]$audience_size_hundreds
# [1] 31321
#
# $audience_views[[4]]$category_id
# [1] 4
#
# $audience_views[[4]]$description
# [1] "All Houseperson"
#
# $audience_views[[4]]$target_size_in_hundreds
# [1] 272070
#
#
# $audience_views[[5]]
# $audience_views[[5]]$audience_code
# [1] "203001_202212_50"
#
# $audience_views[[5]]$audience_size_hundreds
# [1] 5348
#
# $audience_views[[5]]$category_id
# [1] 5
#
# $audience_views[[5]]$description
# [1] "All Children aged 4-15"
#
# $audience_views[[5]]$target_size_in_hundreds
# [1] 95890
#
#
# $audience_views[[6]]
# $audience_views[[6]]$audience_code
# [1] "205001_202212_50"
#
# $audience_views[[6]]$audience_size_hundreds
# [1] 3860
#
# $audience_views[[6]]$category_id
# [1] 6
#
# $audience_views[[6]]$description
# [1] "Adults 16-24"
#
# $audience_views[[6]]$target_size_in_hundreds
# [1] 60650
#
#
# $audience_views[[7]]
# $audience_views[[7]]$audience_code
# [1] "206001_202212_50"
#
# $audience_views[[7]]$audience_size_hundreds
# [1] 10946
#
# $audience_views[[7]]$category_id
# [1] 7
#
# $audience_views[[7]]$description
# [1] "Adults 16-34"
#
# $audience_views[[7]]$target_size_in_hundreds
# [1] 142100
#
#
# $audience_views[[8]]
# $audience_views[[8]]$audience_code
# [1] "102005_202212_50"
#
# $audience_views[[8]]$audience_size_hundreds
# [1] 6112
#
# $audience_views[[8]]$category_id
# [1] 8
#
# $audience_views[[8]]$description
# [1] "Adults 35-44"
#
# $audience_views[[8]]$target_size_in_hundreds
# [1] 82580
#
#
# $audience_views[[9]]
# $audience_views[[9]]$audience_code
# [1] "102006_202212_50"
#
# $audience_views[[9]]$audience_size_hundreds
# [1] 10260
#
# $audience_views[[9]]$category_id
# [1] 9
#
# $audience_views[[9]]$description
# [1] "Adults 45-54"
#
# $audience_views[[9]]$target_size_in_hundreds
# [1] 81910
#
#
# $audience_views[[10]]
# $audience_views[[10]]$audience_code
# [1] "102007_202212_50"
#
# $audience_views[[10]]$audience_size_hundreds
# [1] 10039
#
# $audience_views[[10]]$category_id
# [1] 10
#
# $audience_views[[10]]$description
# [1] "Adults 55-64"
#
# $audience_views[[10]]$target_size_in_hundreds
# [1] 84970
#
#
# $audience_views[[11]]
# $audience_views[[11]]$audience_code
# [1] "102002_202212_50"
#
# $audience_views[[11]]$audience_size_hundreds
# [1] 1043
#
# $audience_views[[11]]$category_id
# [1] 11
#
# $audience_views[[11]]$description
# [1] "Adults 18-20"
#
# $audience_views[[11]]$target_size_in_hundreds
# [1] 19540
#
#
# $audience_views[[12]]
# $audience_views[[12]]$audience_code
# [1] "102003_202212_50"
#
# $audience_views[[12]]$audience_size_hundreds
# [1] 1868
#
# $audience_views[[12]]$category_id
# [1] 12
#
# $audience_views[[12]]$description
# [1] "Adults 21-24"
#
# $audience_views[[12]]$target_size_in_hundreds
# [1] 27740
#
#
# $audience_views[[13]]
# $audience_views[[13]]$audience_code
# [1] "251002_202212_50"
#
# $audience_views[[13]]$audience_size_hundreds
# [1] 4098
#
# $audience_views[[13]]$category_id
# [1] 13
#
# $audience_views[[13]]$description
# [1] "Adults 45-49"
#
# $audience_views[[13]]$target_size_in_hundreds
# [1] 38580
#
#
# $audience_views[[14]]
# $audience_views[[14]]$audience_code
# [1] "212001_202212_50"
#
# $audience_views[[14]]$audience_size_hundreds
# [1] 1068
#
# $audience_views[[14]]$category_id
# [1] 14
#
# $audience_views[[14]]$description
# [1] "Men 16-24"
#
# $audience_views[[14]]$target_size_in_hundreds
# [1] 31300
#
#
# $audience_views[[15]]
# $audience_views[[15]]$audience_code
# [1] "210001_202212_50"
#
# $audience_views[[15]]$audience_size_hundreds
# [1] 4443
#
# $audience_views[[15]]$category_id
# [1] 15
#
# $audience_views[[15]]$description
# [1] "Men 16-34"
#
# $audience_views[[15]]$target_size_in_hundreds
# [1] 72110
#
#
# $audience_views[[16]]
# $audience_views[[16]]$audience_code
# [1] "209006_202212_50"
#
# $audience_views[[16]]$audience_size_hundreds
# [1] 2564
#
# $audience_views[[16]]$category_id
# [1] 16
#
# $audience_views[[16]]$description
# [1] "Men 35-44"
#
# $audience_views[[16]]$target_size_in_hundreds
# [1] 40410
#
#
# $audience_views[[17]]
# $audience_views[[17]]$audience_code
# [1] "209007_202212_50"
#
# $audience_views[[17]]$audience_size_hundreds
# [1] 4304
#
# $audience_views[[17]]$category_id
# [1] 17
#
# $audience_views[[17]]$description
# [1] "Men 45-54"
#
# $audience_views[[17]]$target_size_in_hundreds
# [1] 39870
#
#
# $audience_views[[18]]
# $audience_views[[18]]$audience_code
# [1] "209008_202212_50"
#
# $audience_views[[18]]$audience_size_hundreds
# [1] 4124
#
# $audience_views[[18]]$category_id
# [1] 18
#
# $audience_views[[18]]$description
# [1] "Men 55-64"
#
# $audience_views[[18]]$target_size_in_hundreds
# [1] 41260
#
#
# $audience_views[[19]]
# $audience_views[[19]]$audience_code
# [1] "252002_202212_50"
#
# $audience_views[[19]]$audience_size_hundreds
# [1] 253
#
# $audience_views[[19]]$category_id
# [1] 19
#
# $audience_views[[19]]$description
# [1] "Men 18-20"
#
# $audience_views[[19]]$target_size_in_hundreds
# [1] 10000
#
#
# $audience_views[[20]]
# $audience_views[[20]]$audience_code
# [1] "252003_202212_50"
#
# $audience_views[[20]]$audience_size_hundreds
# [1] 519
#
# $audience_views[[20]]$category_id
# [1] 20
#
# $audience_views[[20]]$description
# [1] "Men 21-24"
#
# $audience_views[[20]]$target_size_in_hundreds
# [1] 14240
#
#
# $audience_views[[21]]
# $audience_views[[21]]$audience_code
# [1] "253001_202212_50"
#
# $audience_views[[21]]$audience_size_hundreds
# [1] 1948
#
# $audience_views[[21]]$category_id
# [1] 21
#
# $audience_views[[21]]$description
# [1] "Men 45-49"
#
# $audience_views[[21]]$target_size_in_hundreds
# [1] 18560
#
#
# $audience_views[[22]]
# $audience_views[[22]]$audience_code
# [1] "217001_202212_50"
#
# $audience_views[[22]]$audience_size_hundreds
# [1] 3805
#
# $audience_views[[22]]$category_id
# [1] 22
#
# $audience_views[[22]]$description
# [1] "Houseperson 16-34"
#
# $audience_views[[22]]$target_size_in_hundreds
# [1] 47730
#
#
# $audience_views[[23]]
# $audience_views[[23]]$audience_code
# [1] "218001_202212_50"
#
# $audience_views[[23]]$audience_size_hundreds
# [1] 7062
#
# $audience_views[[23]]$category_id
# [1] 23
#
# $audience_views[[23]]$description
# [1] "Houseperson 16-44"
#
# $audience_views[[23]]$target_size_in_hundreds
# [1] 93220
#
#
# $audience_views[[24]]
# $audience_views[[24]]$audience_code
# [1] "217002_202212_50"
#
# $audience_views[[24]]$audience_size_hundreds
# [1] 9229
#
# $audience_views[[24]]$category_id
# [1] 24
#
# $audience_views[[24]]$description
# [1] "Houseperson 35-54"
#
# $audience_views[[24]]$target_size_in_hundreds
# [1] 92820
#
#
# $audience_views[[25]]
# $audience_views[[25]]$audience_code
# [1] "225001_202212_50"
#
# $audience_views[[25]]$audience_size_hundreds
# [1] 12770
#
# $audience_views[[25]]$category_id
# [1] 25
#
# $audience_views[[25]]$description
# [1] "Individuals AB"
#
# $audience_views[[25]]$target_size_in_hundreds
# [1] 156590
#
#
# $audience_views[[26]]
# $audience_views[[26]]$audience_code
# [1] "225002_202212_50"
#
# $audience_views[[26]]$audience_size_hundreds
# [1] 21321
#
# $audience_views[[26]]$category_id
# [1] 26
#
# $audience_views[[26]]$description
# [1] "Individuals C1"
#
# $audience_views[[26]]$target_size_in_hundreds
# [1] 186530
#
#
# $audience_views[[27]]
# $audience_views[[27]]$audience_code
# [1] "225003_202212_50"
#
# $audience_views[[27]]$audience_size_hundreds
# [1] 15013
#
# $audience_views[[27]]$category_id
# [1] 27
#
# $audience_views[[27]]$description
# [1] "Individuals C2"
#
# $audience_views[[27]]$target_size_in_hundreds
# [1] 133470
#
#
# $audience_views[[28]]
# $audience_views[[28]]$audience_code
# [1] "224001_202212_50"
#
# $audience_views[[28]]$audience_size_hundreds
# [1] 30884
#
# $audience_views[[28]]$category_id
# [1] 28
#
# $audience_views[[28]]$description
# [1] "Adults ABC1"
#
# $audience_views[[28]]$target_size_in_hundreds
# [1] 291320
#
#
# $audience_views[[29]]
# $audience_views[[29]]$audience_code
# [1] "223001_202212_50"
#
# $audience_views[[29]]$audience_size_hundreds
# [1] 11420
#
# $audience_views[[29]]$category_id
# [1] 29
#
# $audience_views[[29]]$description
# [1] "Adults AB"
#
# $audience_views[[29]]$target_size_in_hundreds
# [1] 131530
#
#
# $audience_views[[30]]
# $audience_views[[30]]$audience_code
# [1] "223003_202212_50"
#
# $audience_views[[30]]$audience_size_hundreds
# [1] 13949
#
# $audience_views[[30]]$category_id
# [1] 30
#
# $audience_views[[30]]$description
# [1] "Adults C2"
#
# $audience_views[[30]]$target_size_in_hundreds
# [1] 112430
#
#
# $audience_views[[31]]
# $audience_views[[31]]$audience_code
# [1] "244001_202212_50"
#
# $audience_views[[31]]$audience_size_hundreds
# [1] 12317
#
# $audience_views[[31]]$category_id
# [1] 31
#
# $audience_views[[31]]$description
# [1] "Men ABC1"
#
# $audience_views[[31]]$target_size_in_hundreds
# [1] 139330
#
#
# $audience_views[[32]]
# $audience_views[[32]]$audience_code
# [1] "243001_202212_50"
#
# $audience_views[[32]]$audience_size_hundreds
# [1] 4614
#
# $audience_views[[32]]$category_id
# [1] 32
#
# $audience_views[[32]]$description
# [1] "Men AB"
#
# $audience_views[[32]]$target_size_in_hundreds
# [1] 65820
#
#
# $audience_views[[33]]
# $audience_views[[33]]$audience_code
# [1] "243003_202212_50"
#
# $audience_views[[33]]$audience_size_hundreds
# [1] 6050
#
# $audience_views[[33]]$category_id
# [1] 33
#
# $audience_views[[33]]$description
# [1] "Men C2"
#
# $audience_views[[33]]$target_size_in_hundreds
# [1] 60320
#
#
# $audience_views[[34]]
# $audience_views[[34]]$audience_code
# [1] "254001_202212_50"
#
# $audience_views[[34]]$audience_size_hundreds
# [1] 1663
#
# $audience_views[[34]]$category_id
# [1] 34
#
# $audience_views[[34]]$description
# [1] "Adults ABC1 16-24"
#
# $audience_views[[34]]$target_size_in_hundreds
# [1] 33300
#
#
# $audience_views[[35]]
# $audience_views[[35]]$audience_code
# [1] "227001_202212_50"
#
# $audience_views[[35]]$audience_size_hundreds
# [1] 5982
#
# $audience_views[[35]]$category_id
# [1] 35
#
# $audience_views[[35]]$description
# [1] "Adults ABC1 16-34"
#
# $audience_views[[35]]$target_size_in_hundreds
# [1] 79720
#
#
# $audience_views[[36]]
# $audience_views[[36]]$audience_code
# [1] "228001_202212_50"
#
# $audience_views[[36]]$audience_size_hundreds
# [1] 10072
#
# $audience_views[[36]]$category_id
# [1] 36
#
# $audience_views[[36]]$description
# [1] "Adults ABC1 16-44"
#
# $audience_views[[36]]$target_size_in_hundreds
# [1] 128750
#
#
# $audience_views[[37]]
# $audience_views[[37]]$audience_code
# [1] "227002_202212_50"
#
# $audience_views[[37]]$audience_size_hundreds
# [1] 10025
#
# $audience_views[[37]]$category_id
# [1] 37
#
# $audience_views[[37]]$description
# [1] "Adults ABC1 35-54"
#
# $audience_views[[37]]$target_size_in_hundreds
# [1] 98200
#
#
# $audience_views[[38]]
# $audience_views[[38]]$audience_code
# [1] "255001_202212_50"
#
# $audience_views[[38]]$audience_size_hundreds
# [1] 391
#
# $audience_views[[38]]$category_id
# [1] 38
#
# $audience_views[[38]]$description
# [1] "Men ABC1 16-24"
#
# $audience_views[[38]]$target_size_in_hundreds
# [1] 16760
#
#
# $audience_views[[39]]
# $audience_views[[39]]$audience_code
# [1] "246001_202212_50"
#
# $audience_views[[39]]$audience_size_hundreds
# [1] 2573
#
# $audience_views[[39]]$category_id
# [1] 39
#
# $audience_views[[39]]$description
# [1] "Men ABC1 16-34"
#
# $audience_views[[39]]$target_size_in_hundreds
# [1] 39830
#
#
# $audience_views[[40]]
# $audience_views[[40]]$audience_code
# [1] "257001_202212_50"
#
# $audience_views[[40]]$audience_size_hundreds
# [1] 4328
#
# $audience_views[[40]]$category_id
# [1] 40
#
# $audience_views[[40]]$description
# [1] "Men ABC1 16-44"
#
# $audience_views[[40]]$target_size_in_hundreds
# [1] 63650
#
#
# $audience_views[[41]]
# $audience_views[[41]]$audience_code
# [1] "246002_202212_50"
#
# $audience_views[[41]]$audience_size_hundreds
# [1] 4305
#
# $audience_views[[41]]$category_id
# [1] 41
#
# $audience_views[[41]]$description
# [1] "Men ABC1 35-54"
#
# $audience_views[[41]]$target_size_in_hundreds
# [1] 47230
#
#
# $audience_views[[42]]
# $audience_views[[42]]$audience_code
# [1] "215001_202212_50"
#
# $audience_views[[42]]$audience_size_hundreds
# [1] 17435
#
# $audience_views[[42]]$category_id
# [1] 42
#
# $audience_views[[42]]$description
# [1] "Houseperson ABC1"
#
# $audience_views[[42]]$target_size_in_hundreds
# [1] 149850
#
#
# $audience_views[[43]]
# $audience_views[[43]]$audience_code
# [1] "242001_202212_50"
#
# $audience_views[[43]]$audience_size_hundreds
# [1] 2048
#
# $audience_views[[43]]$category_id
# [1] 43
#
# $audience_views[[43]]$description
# [1] "Houseperson ABC1 16-34"
#
# $audience_views[[43]]$target_size_in_hundreds
# [1] 26190
#
#
# $audience_views[[44]]
# $audience_views[[44]]$audience_code
# [1] "229001_202212_50"
#
# $audience_views[[44]]$audience_size_hundreds
# [1] 24165
#
# $audience_views[[44]]$category_id
# [1] 44
#
# $audience_views[[44]]$description
# [1] "Adults working full-time"
#
# $audience_views[[44]]$target_size_in_hundreds
# [1] 249920
#
#
# $audience_views[[45]]
# $audience_views[[45]]$audience_code
# [1] "213001_202212_50"
#
# $audience_views[[45]]$audience_size_hundreds
# [1] 13665
#
# $audience_views[[45]]$category_id
# [1] 45
#
# $audience_views[[45]]$description
# [1] "Men working full-time"
#
# $audience_views[[45]]$target_size_in_hundreds
# [1] 145970
#
#
# $audience_views[[46]]
# $audience_views[[46]]$audience_code
# [1] "219001_202212_50"
#
# $audience_views[[46]]$audience_size_hundreds
# [1] 10735
#
# $audience_views[[46]]$category_id
# [1] 46
#
# $audience_views[[46]]$description
# [1] "Houseperson working full-time"
#
# $audience_views[[46]]$target_size_in_hundreds
# [1] 110990
#
#
# $audience_views[[47]]
# $audience_views[[47]]$audience_code
# [1] "248001_202212_50"
#
# $audience_views[[47]]$audience_size_hundreds
# [1] 8459
#
# $audience_views[[47]]$category_id
# [1] 47
#
# $audience_views[[47]]$description
# [1] "Men ABC1 working full-time"
#
# $audience_views[[47]]$target_size_in_hundreds
# [1] 86850
#
#
# $audience_views[[48]]
# $audience_views[[48]]$audience_code
# [1] "249001_202212_50"
#
# $audience_views[[48]]$audience_size_hundreds
# [1] 3019
#
# $audience_views[[48]]$category_id
# [1] 48
#
# $audience_views[[48]]$description
# [1] "Men AB working full-time"
#
# $audience_views[[48]]$target_size_in_hundreds
# [1] 41450
#
#
# $audience_views[[49]]
# $audience_views[[49]]$audience_code
# [1] "220001_202212_50"
#
# $audience_views[[49]]$audience_size_hundreds
# [1] 6951
#
# $audience_views[[49]]$category_id
# [1] 49
#
# $audience_views[[49]]$description
# [1] "Houseperson with children 0-15"
#
# $audience_views[[49]]$target_size_in_hundreds
# [1] 70060
#
#
# $audience_views[[50]]
# $audience_views[[50]]$audience_code
# [1] "221001_202212_50"
#
# $audience_views[[50]]$audience_size_hundreds
# [1] 2730
#
# $audience_views[[50]]$category_id
# [1] 50
#
# $audience_views[[50]]$description
# [1] "Houseperson with children 0-3"
#
# $audience_views[[50]]$target_size_in_hundreds
# [1] 23070
#
#
# $audience_views[[51]]
# $audience_views[[51]]$audience_code
# [1] "204001_202212_50"
#
# $audience_views[[51]]$audience_size_hundreds
# [1] 2712
#
# $audience_views[[51]]$category_id
# [1] 51
#
# $audience_views[[51]]$description
# [1] "Children 04-09"
#
# $audience_views[[51]]$target_size_in_hundreds
# [1] 47460
#
#
# $audience_views[[52]]
# $audience_views[[52]]$audience_code
# [1] "256001_202212_50"
#
# $audience_views[[52]]$audience_size_hundreds
# [1] 1248
#
# $audience_views[[52]]$category_id
# [1] 52
#
# $audience_views[[52]]$description
# [1] "Children 04-06"
#
# $audience_views[[52]]$target_size_in_hundreds
# [1] 24040
#
#
# $audience_views[[53]]
# $audience_views[[53]]$audience_code
# [1] "204002_202212_50"
#
# $audience_views[[53]]$audience_size_hundreds
# [1] 1244
#
# $audience_views[[53]]$category_id
# [1] 53
#
# $audience_views[[53]]$description
# [1] "Children 10-12"
#
# $audience_views[[53]]$target_size_in_hundreds
# [1] 24640
#
#
# $audience_views[[54]]
# $audience_views[[54]]$audience_code
# [1] "250001_202212_50"
#
# $audience_views[[54]]$audience_size_hundreds
# [1] 2907
#
# $audience_views[[54]]$category_id
# [1] 54
#
# $audience_views[[54]]$description
# [1] "Boys 04-15"
#
# $audience_views[[54]]$target_size_in_hundreds
# [1] 49300
#
#
# $audience_views[[55]]
# $audience_views[[55]]$audience_code
# [1] "209001_202212_50"
#
# $audience_views[[55]]$audience_size_hundreds
# [1] 1449
#
# $audience_views[[55]]$category_id
# [1] 55
#
# $audience_views[[55]]$description
# [1] "Boys 04-09"
#
# $audience_views[[55]]$target_size_in_hundreds
# [1] 24510
#
#
# $audience_views[[56]]
# $audience_views[[56]]$audience_code
# [1] "209002_202212_50"
#
# $audience_views[[56]]$audience_size_hundreds
# [1] 627
#
# $audience_views[[56]]$category_id
# [1] 56
#
# $audience_views[[56]]$description
# [1] "Boys 10-12"
#
# $audience_views[[56]]$target_size_in_hundreds
# [1] 12720
#
#
# $audience_views[[57]]
# $audience_views[[57]]$audience_code
# [1] "266001_202212_50"
#
# $audience_views[[57]]$audience_size_hundreds
# [1] 8806
#
# $audience_views[[57]]$category_id
# [1] 57
#
# $audience_views[[57]]$description
# [1] "Adults, Lightest Third"
#
# $audience_views[[57]]$target_size_in_hundreds
# [1] 171580
#
#
# $audience_views[[58]]
# $audience_views[[58]]$audience_code
# [1] "260001_202212_50"
#
# $audience_views[[58]]$audience_size_hundreds
# [1] 2606
#
# $audience_views[[58]]$category_id
# [1] 58
#
# $audience_views[[58]]$description
# [1] "Adults, Lightest Sixth"
#
# $audience_views[[58]]$target_size_in_hundreds
# [1] 85800
#
#
# $audience_views[[59]]
# $audience_views[[59]]$audience_code
# [1] "267001_202212_50"
#
# $audience_views[[59]]$audience_size_hundreds
# [1] 4071
#
# $audience_views[[59]]$category_id
# [1] 59
#
# $audience_views[[59]]$description
# [1] "ABC1 Adults, Lightest Third"
#
# $audience_views[[59]]$target_size_in_hundreds
# [1] 97120
#
#
# $audience_views[[60]]
# $audience_views[[60]]$audience_code
# [1] "268001_202212_50"
#
# $audience_views[[60]]$audience_size_hundreds
# [1] 1528
#
# $audience_views[[60]]$category_id
# [1] 60
#
# $audience_views[[60]]$description
# [1] "Adults 16-34, Lightest Third"
#
# $audience_views[[60]]$target_size_in_hundreds
# [1] 47380

# %% [markdown]
# ## Querying the API with baRb
#
# Like pybarb, baRb will handle the pagination for you. First load the baRb package into memory.

# %%
library(baRb)

# %% [markdown]
# To use baRb to connect to Barb API we need to store the credentials environment variables. This can be done using the following code:

# %%
Sys.setenv(BARB_API_USERNAME = creds$email)
Sys.setenv(BARB_API_PASSWORD = creds$password)

# %% [markdown]
# Now we can use `barb_get_programmes` method to query the programme ratings endpoint. This function will handle the pagination for us.

# %%
bbc_1_xmas <- barb_get_programmes ("min_transmission_date" = "2022-12-25",
      "max_transmission_date" = "2022-12-31",
      "station_code" = 10,
      "consolidated" = TRUE
    )

# %%
head(bbc_1_xmas)
