# %% [markdown]
# # Pulling data from the viewing endpoint using pybarb
#
# In this demo we will show you how to pull data from the asynchronus viewing endpoint and then manipulate it using the pybarb library. We will cover pulling data for all activities and then look at how you can limit the request to specific activities
#
# Note the full API documentation can be found [here](https://barb-api.co.uk/api-docs).
#
# It might also be useful to consult the [Getting Started](https://barb-api.co.uk/api-docs#section/Getting-started) section for information about authentication and basic API usage.

# %% [markdown]
# ## Pulling all viewing data for a particular station and channel
#
# As usual we begin by connecting to the API and authenticating.

# %%
import json
import pybarb as pb

# Set the working directory
working_directory = '/Users/simon_business/Documents/disposable/clients/BARB/'

# Get the access token
with open(working_directory + "creds.json") as file:
    creds = json.load(file)

# Create a BarbAPI object and connect
barb_api = pb.BarbAPI(creds)
barb_api.connect()

# %% [markdown]
# We would like one day's worth of viewing data (2023-07-06) for BBC1 East viewing station and the BBC East Region panel.
#
# First we need to look up the viewing station and panels to check we have the correct query parameters

# %%
barb_api.list_panels("BBC")
# Out:
# ['BBC Network',
#  'BBC East Region',
#  'BBC West Region',
#  'BBC South West Region',
#  'BBC South Region',
#  'BBC Yorkshire & Lincolnshire',
#  'BBC North East & Cumbria',
#  'BBC North West Region',
#  'BBC Scotland Region',
#  'BBC Ulster Region',
#  'BBC Wales Region',
#  'BBC Midlands West',
#  'BBC Midlands East',
#  'BBC London',
#  'BBC South East']

# %%
barb_api.list_viewing_stations("BBC1")
# Out:
# ['BBC1 Midlands West',
#  'BBC1 East',
#  'BBC1 West',
#  'BBC1 South West',
#  'BBC1 South',
#  'BBC1 Yorks/Lincs',
#  'BBC1 North East/Cumbria',
#  'BBC1 North West',
#  'BBC1 Scotland',
#  'BBC1 Wales',
#  'BBC1 Northern Ireland',
#  'BBC1 Midlands East',
#  'BBC1 London',
#  'BBC1 South East']

# %% [markdown]
# Next we need to request the data sets from the asynchronous API. We will use the `pybarb` package to do this.

# %%
barb_api.viewing(min_session_date="2023-07-06", max_session_date="2023-07-06", 
                 viewing_station="BBC1 East", panel="BBC East Region")
# Out:
# Job successfully started. The job id is 2c223027-1a5b-48d3-be0a-5bfef6f652c0

# %% [markdown]
# Once the job has started we can use the ping_job_status method to check the status of the job. It will check the status every 60 seconds until the job is complete.

# %%
barb_api.ping_job_status()
# Out:
# Job not ready yet. Sleeping for 60 seconds.
# Job complete. 1 files are ready for download.

# %% [markdown]
# Now we can download the data using the `get_asynch_files` method.

# %%
viewing_results_set = barb_api.get_asynch_files()

# %% [markdown]
# In its raw form  we can see many of the cells contain json. We will need to unpack this.

# %%
viewing_results_set.api_response_data.head(5)
# Out:
#   STANDARD_DATE_OF_ACTIVITY  \
# 0                2023-07-06
# 1                2023-07-06
# 2                2023-07-06
# 3                2023-07-06
# 4                2023-07-06
#
#                                        SESSION_START  \
# 0  {'barb_polling_datetime': '2023-07-06 18:19:00...
# 1  {'barb_polling_datetime': '2023-07-06 12:59:00...
# 2  {'barb_polling_datetime': '2023-07-06 18:56:00...
# 3  {'barb_polling_datetime': '2023-07-06 20:59:00...
# 4  {'barb_polling_datetime': '2023-07-06 22:48:00...
#
#                                          SESSION_END  \
# 0  {'barb_polling_datetime': '2023-07-06 18:21:00...
# 1  {'barb_polling_datetime': '2023-07-06 13:45:00...
# 2  {'barb_polling_datetime': '2023-07-06 20:28:00...
# 3  {'barb_polling_datetime': '2023-07-06 21:02:00...
# 4  {'barb_polling_datetime': '2023-07-06 23:18:00...
#
#                                            HOUSEHOLD  \
# 0  {'bbc_itv_segment': 'bbc east / east of englan...
# 1  {'bbc_itv_segment': 'bbc east / east of englan...
# 2  {'bbc_itv_segment': 'bbc east / east of englan...
# 3  {'bbc_itv_segment': 'bbc east / east of englan...
# 4  {'bbc_itv_segment': 'bbc east / east of englan...
#
#                                               DEVICE  \
# 0  {'date_valid_for': '2023-07-06', 'device_numbe...
# 1  {'date_valid_for': '2023-07-06', 'device_numbe...
# 2  {'date_valid_for': '2023-07-06', 'device_numbe...
# 3  {'date_valid_for': '2023-07-06', 'device_numbe...
# 4  {'date_valid_for': '2023-07-06', 'device_numbe...
#
#                                        PANEL_VIEWERS GUEST_VIEWERS  \
# 0  [{'date_of_birth': '1977-02-01', 'dependency_o...            {}
# 1  [{'date_of_birth': '1948-04-01', 'dependency_o...            {}
# 2  [{'date_of_birth': '1954-12-01', 'dependency_o...            {}
# 3  [{'date_of_birth': '1949-01-01', 'dependency_o...            {}
# 4  [{'date_of_birth': '1949-11-01', 'dependency_o...            {}
#
#                                    PROGRAMMES_VIEWED SPOTS_VIEWED  \
# 0  [{'broadcaster_premier': True, 'broadcaster_tr...           []
# 1  [{'broadcaster_premier': True, 'broadcaster_tr...           []
# 2  [{'broadcaster_premier': True, 'broadcaster_tr...           []
# 3  [{'broadcaster_premier': True, 'broadcaster_tr...           []
# 4  [{'broadcaster_premier': True, 'broadcaster_tr...           []
#
#                                      VIEWING_STATION  ...  \
# 0  {'viewing_station_code': 32, 'viewing_station_...  ...
# 1  {'viewing_station_code': 32, 'viewing_station_...  ...
# 2  {'viewing_station_code': 32, 'viewing_station_...  ...
# 3  {'viewing_station_code': 32, 'viewing_station_...  ...
# 4  {'viewing_station_code': 32, 'viewing_station_...  ...
#
#               PLATFORM                             ACTIVITY_TYPE  \
# 0  digital terrestrial  live viewing (excl targeted advertising)
# 1  digital terrestrial  live viewing (excl targeted advertising)
# 2  digital terrestrial  live viewing (excl targeted advertising)
# 3  digital terrestrial  live viewing (excl targeted advertising)
# 4  digital terrestrial  live viewing (excl targeted advertising)
#
#   CONTENT_ASSET_ITEM_OFFSET PLAYBACK_TYPE SKY_ULTRA_HD  START_OF_RECORDING  \
# 0                         0       unknown        False                  {}
# 1                         0       unknown        False                  {}
# 2                         0       unknown        False                  {}
# 3                         0       unknown        False                  {}
# 4                         0       unknown        False                  {}
#
#   TARGETED_PROMOTION  VOD_INDICATOR  \
# 0              False  not on-demand
# 1              False  not on-demand
# 2              False  not on-demand
# 3              False  not on-demand
# 4              False  not on-demand
#
#                                         VOD_PROVIDER REPLICATE_ID
# 0  {'vod_provider': 'unknown', 'vod_service': 'un...         None
# 1  {'vod_provider': 'unknown', 'vod_service': 'un...         None
# 2  {'vod_provider': 'unknown', 'vod_service': 'un...         None
# 3  {'vod_provider': 'unknown', 'vod_service': 'un...         None
# 4  {'vod_provider': 'unknown', 'vod_service': 'un...         None
#
# [5 rows x 21 columns]

# %% [markdown]
# We can either save it as json using the `to_json` method...

# %%
viewing_results_set.to_json("results.json")

# %% [markdown]
# Or we can use the `to_dataframe` method to reshape the data so that we have one row per viewer per programme.

# %%
df = viewing_results_set.to_dataframe(unpack=["viewers", "programmes"])
df.head()
# Out:
#     session_start_datetime programme_start_datetime  \
# 0  2023-07-06 18:19:00.000      2023-07-06 18:00:03
# 4  2023-07-06 12:59:00.000      2023-07-06 13:33:30
# 5  2023-07-06 12:59:00.000      2023-07-06 13:33:30
# 6  2023-07-06 12:59:00.000      2023-07-06 13:00:00
# 7  2023-07-06 12:59:00.000      2023-07-06 13:00:00
#
#                                  programme_name date_of_birth  \
# 0                  BBC News at Six: Series 2023    1977-02-01
# 4  East Midlands Today: Series 2023, Episode 69    1948-04-01
# 5  East Midlands Today: Series 2023, Episode 69    1946-01-01
# 6                  BBC News at One: Series 2023    1948-04-01
# 7                  BBC News at One: Series 2023    1946-01-01
#
#   dependency_of_children disability  ethnic_origin  \
# 0           unclassified         no  white british
# 4           unclassified         no  white british
# 5           unclassified         no  white british
# 6           unclassified         no  white british
# 7           unclassified         no  white british
#
#                        gaelic_language  \
# 0  not gaelic speaking/not in scotland
# 4  not gaelic speaking/not in scotland
# 5  not gaelic speaking/not in scotland
# 6  not gaelic speaking/not in scotland
# 7  not gaelic speaking/not in scotland
#
#                          household_status  \
# 0  both houseperson and head of household
# 4   houseperson and not Head of household
# 5   head of household and not houseperson
# 6   houseperson and not Head of household
# 7   head of household and not houseperson
#
#                                           life_stage  ... number_of_tv_sets  \
# 0  either youngest children 5-9 includes single p...  ...                 3
# 4                        couple no children aged 55+  ...                 2
# 5                        couple no children aged 55+  ...                 2
# 6                        couple no children aged 55+  ...                 2
# 7                        couple no children aged 55+  ...                 2
#
#   number_of_vcrs         panel_membership_status  \
# 0              0  home on panel (valid reporter)
# 4              0  home on panel (valid reporter)
# 5              0  home on panel (valid reporter)
# 6              0  home on panel (valid reporter)
# 7              0  home on panel (valid reporter)
#
#                      presence_of_children replication_factor social_class  \
# 0  with children aged 4-9 and 10-15 years                 20           C1
# 4                             no children                 11           C1
# 5                             no children                 11           C1
# 6                             no children                 11           C1
# 7                             no children                 11           C1
#
#   welsh_speaking_home device_number device_on_panel device_type
# 0  non welsh speaking             1            True          tv
# 4  non welsh speaking             1            True          tv
# 5  non welsh speaking             1            True          tv
# 6  non welsh speaking             1            True          tv
# 7  non welsh speaking             1            True          tv
#
# [5 rows x 44 columns]

# %%
df.columns
# Out:
# Index(['session_start_datetime', 'programme_start_datetime', 'programme_name',
#        'date_of_birth', 'dependency_of_children', 'disability',
#        'ethnic_origin', 'gaelic_language', 'household_status', 'life_stage',
#        'marital_status', 'person_membership_status', 'person_number',
#        'sex_code', 'terminal_age_of_education', 'welsh_language',
#        'working_status', 'bbc_itv_segment', 'bbc_region_code',
#        'bbc_sub_reporting_region', 'broadband', 'date_valid_for',
#        'demographic_cell', 'household_number', 'language_spoken_at_home',
#        'mosaic_classification_2014', 'number_of_computers',
#        'number_of_dvd_players_not_recorders', 'number_of_dvd_recorders',
#        'number_of_dvds', 'number_of_other_pvrs', 'number_of_people',
#        'number_of_pvrs', 'number_of_sky_plus_pvrs', 'number_of_tv_sets',
#        'number_of_vcrs', 'panel_membership_status', 'presence_of_children',
#        'replication_factor', 'social_class', 'welsh_speaking_home',
#        'device_number', 'device_on_panel', 'device_type'],
#       dtype='object')

# %% [markdown]
# ## Pulling data for SVOD only
#
# To restrict the returned data to SVOD only we set the `activity_type`` parameter to `tv_non_linear`. Here we bring back all data for Netflix viewing on the BBC East Region panel.

# %%
barb_api.viewing(min_session_date="2023-07-06", max_session_date="2023-07-06", 
                  viewing_station="Netflix", panel="BBC East Region", activity_type="tv_non_linear")
barb_api.ping_job_status()
viewing_results_set = barb_api.get_asynch_files()
df = viewing_results_set.to_dataframe(unpack=["viewers", "programmes"])
df.head()
# Out:
# Job successfully started. The job id is 61b2f92a-5cc5-4e5b-afc0-2962ff4ab026
# Job not ready yet. Sleeping for 60 seconds.
# Job not ready yet. Sleeping for 60 seconds.
# Job complete. 1 files are ready for download.
#     session_start_datetime                           programme_name  \
# 0  2023-07-06 18:32:00.000     Shameless USA: Series 10, Episode 12
# 1  2023-07-06 18:55:00.000             Lucifer: Series 3, Episode 2
# 2  2023-07-06 05:18:00.000       Young Sheldon: Series 5, Episode 5
# 3  2023-07-06 06:23:00.000               FILM: The Uninvited (2009)
# 4  2023-07-06 20:43:00.000  Brooklyn Nine-Nine: Series 7, Episode 9
#
#   date_of_birth dependency_of_children         disability  ethnic_origin  \
# 0    1975-09-01           unclassified  yes limited a lot    other White
# 1    1973-04-01           unclassified                 no  white british
# 2    1955-01-01           unclassified                 no  white british
# 3    1955-01-01           unclassified                 no  white british
# 4    1997-03-01           unclassified                 no  white british
#
#                        gaelic_language  \
# 0  not gaelic speaking/not in scotland
# 1  not gaelic speaking/not in scotland
# 2  not gaelic speaking/not in scotland
# 3  not gaelic speaking/not in scotland
# 4  not gaelic speaking/not in scotland
#
#                          household_status  \
# 0  both houseperson and head of household
# 1   head of household and not houseperson
# 2  both houseperson and head of household
# 3  both houseperson and head of household
# 4   head of household and not houseperson
#
#                                           life_stage  \
# 0  single no children on own or with friends aged...
# 1             either children 16+ none 0-15 aged 35+
# 2                 single no children on own aged 55+
# 3                 single no children on own aged 55+
# 4                      couple no children aged 16-34
#
#                   marital_status  ... number_of_tv_sets  number_of_vcrs  \
# 0  single / divorced / separated  ...                 1               0
# 1    married / living as married  ...                 3               0
# 2  single / divorced / separated  ...                 1               0
# 3  single / divorced / separated  ...                 1               0
# 4    married / living as married  ...                 1               0
#
#           panel_membership_status presence_of_children replication_factor  \
# 0  home on panel (valid reporter)          no children                 16
# 1  home on panel (valid reporter)          no children                 17
# 2  home on panel (valid reporter)          no children                 17
# 3  home on panel (valid reporter)          no children                 17
# 4  home on panel (valid reporter)          no children                 15
#
#   social_class welsh_speaking_home device_number device_on_panel  device_type
# 0            E  non welsh speaking             1            True           tv
# 1           C1  non welsh speaking             2            True           tv
# 2            D  non welsh speaking             1            True           tv
# 3            D  non welsh speaking             1            True           tv
# 4           C1  non welsh speaking             1            True           tv
#
# [5 rows x 43 columns]

# %% [markdown]
# ## Pulling data only for viewing that took place on tablets, PCs and smartphones.
# This is done by setting the `activity_type` parameter to "online_devices". Here we bring back all data for viewing on tablets, PCs and smartphones of the station "BBC London" by those panelists who live in the BBC London region.

# %%
barb_api.viewing(min_session_date="2023-07-06", max_session_date="2023-07-06", 
                  viewing_station="BBC1 London", panel="BBC London", activity_type="online_devices")
barb_api.ping_job_status()
viewing_results_set = barb_api.get_asynch_files()
df = viewing_results_set.to_dataframe(unpack=["viewers", "programmes"])
df.head()
# Out:
# Job successfully started. The job id is e45ba72d-7cb4-40b7-b4e4-4a3fcc91c500
# Job not ready yet. Sleeping for 60 seconds.
# Job not ready yet. Sleeping for 60 seconds.
# Job complete. 1 files are ready for download.
#      session_start_datetime programme_start_datetime  \
# 0   2023-07-06 01:30:16.000      2023-07-06 01:33:57
# 2   2023-07-06 01:30:16.000      2023-07-06 01:28:55
# 8   2023-07-06 19:04:28.000      2023-07-07 22:32:59
# 9   2023-07-06 19:04:28.000      2023-07-06 22:44:56
# 10  2023-07-06 19:04:28.000      2023-07-06 23:19:47
#
#                              programme_name date_of_birth  \
# 0               Joins BBC News: Series 2023    1979-02-01
# 2   Weather for the Week Ahead: Series 2023    1979-02-01
# 8      South Today: Series 2023, Episode 84    1952-02-01
# 9              BBC News at Ten: Series 2023    1952-02-01
# 10   Question Time: Series 2023, Episode 37    1952-02-01
#
#    dependency_of_children disability    ethnic_origin  \
# 0            unclassified         no      other White
# 2            unclassified         no      other White
# 8            unclassified         no  black - african
# 9            unclassified         no  black - african
# 10           unclassified         no  black - african
#
#                         gaelic_language  \
# 0   not gaelic speaking/not in scotland
# 2   not gaelic speaking/not in scotland
# 8   not gaelic speaking/not in scotland
# 9   not gaelic speaking/not in scotland
# 10  not gaelic speaking/not in scotland
#
#                              household_status  \
# 0   neither houseperson nor head of household
# 2   neither houseperson nor head of household
# 8       head of household and not houseperson
# 9       head of household and not houseperson
# 10      head of household and not houseperson
#
#                                 life_stage  ... number_of_tv_sets  \
# 0            couple no children aged 35-54  ...                 1
# 2            couple no children aged 35-54  ...                 1
# 8   either children 16+ none 0-15 aged 35+  ...                 1
# 9   either children 16+ none 0-15 aged 35+  ...                 1
# 10  either children 16+ none 0-15 aged 35+  ...                 1
#
#    number_of_vcrs         panel_membership_status presence_of_children  \
# 0               0  home on panel (valid reporter)          no children
# 2               0  home on panel (valid reporter)          no children
# 8               0  home on panel (valid reporter)          no children
# 9               0  home on panel (valid reporter)          no children
# 10              0  home on panel (valid reporter)          no children
#
#    replication_factor social_class welsh_speaking_home device_number  \
# 0                  44           AB  non welsh speaking            11
# 2                  44           AB  non welsh speaking            11
# 8                  17           C2  non welsh speaking            25
# 9                  17           C2  non welsh speaking            25
# 10                 17           C2  non welsh speaking            25
#
#    device_on_panel device_type
# 0             True    computer
# 2             True    computer
# 8             True      tablet
# 9             True      tablet
# 10            True      tablet
#
# [5 rows x 44 columns]

# %% [markdown]
# We can check the number of rows for each device type.

# %%
df.device_type.value_counts()
# Out:
# device_type
# tablet        1637
# computer       749
# smartphone     273
# Name: count, dtype: int64
