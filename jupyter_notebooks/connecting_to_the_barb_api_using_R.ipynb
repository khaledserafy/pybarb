# %% [markdown]
# # Connecting to the Barb API using R
#
# In this demo we will show you how to connect to the Barb API using R. We will do this first without making use of the baRb package (as you may wish to develop your own software from scratch). We will then show you how to use the baRb package to make the same request.
#
# Note the full API documentation can be found [here](https://barb-api.co.uk/api-docs).
#
# It might also be useful to consult the [Getting Started](https://barb-api.co.uk/api-docs#section/Getting-started) section for information about authentication and basic API usage.

# %% [markdown]
# ## Connecting to the API without baRb
#
# First we load all the libraries we will need to access the API.

# %%
library(tidyr)
library(jsonlite)

working_directory <- '/Users/simon_business/Documents/disposable/clients/BARB/'

# %% [markdown]
# ### Getting the access token
#
# Following the steps in the [API Getting Started Guide ](https://barb-api.co.uk/api-docs#section/Getting-started) we run some python code to get an access token. This code uses your account details to get an access token from the API. Your creds.json file should include the email and password supplied by BARB. For example:
#
# ```
# {"email": "me@coppelia.io", "password": "INSERT PASSWORD"}
# ```

# %%
# Read the json file containing the credentials
creds <- fromJSON(paste0(working_directory, "creds.json"))

# Get the token
token <- httr::POST(
url = "https://barb-api.co.uk/api/v1/auth/token/",
body = toJSON(creds, auto_unbox=TRUE),
httr::content_type("application/json")
)

# %% [markdown]
# ### Using the access token to query the API
#
# Let's make a very simple call to the API to demonstrate that the access token works. We'll use the `get` method from the `requests` library to make a `GET` request to the `barb-api.co.uk/api/v1/panels` endpoint. We'll pass the access token as a parameter in the request.

# %%
response <- httr::GET(url = "https://barb-api.co.uk/api/v1/panels/",
                    httr::add_headers(Authorization = paste0('Bearer ',
                                                                httr::content(token, as = "parsed")$access)),
                    query = list())

raw_json <- response %>%
httr::content()
print(raw_json)
# Out:
# [[1]]
# [[1]]$panel_code
# [1] 1
#
# [[1]]$panel_region
# [1] "London - ITV,C4,ITV Breakfast"
#
# [[1]]$is_macro_region
# [1] FALSE
#
#
# [[2]]
# [[2]]$panel_code
# [1] 4
#
# [[2]]$panel_region
# [1] "Midlands -ITV,C4,ITV Breakfast"
#
# [[2]]$is_macro_region
# [1] FALSE
#
#
# [[3]]
# [[3]]$panel_code
# [1] 7
#
# [[3]]$panel_region
# [1] "North West"
#
# [[3]]$is_macro_region
# [1] FALSE
#
#
# [[4]]
# [[4]]$panel_code
# [1] 11
#
# [[4]]$panel_region
# [1] "Yorkshire"
#
# [[4]]$is_macro_region
# [1] FALSE
#
#
# [[5]]
# [[5]]$panel_code
# [1] 12
#
# [[5]]$panel_region
# [1] "North East"
#
# [[5]]$is_macro_region
# [1] FALSE
#
#
# [[6]]
# [[6]]$panel_code
# [1] 17
#
# [[6]]$panel_region
# [1] "Scotland - ITV,ITV Breakfast"
#
# [[6]]$is_macro_region
# [1] FALSE
#
#
# [[7]]
# [[7]]$panel_code
# [1] 18
#
# [[7]]$panel_region
# [1] "Wales & West Macro"
#
# [[7]]$is_macro_region
# [1] TRUE
#
#
# [[8]]
# [[8]]$panel_code
# [1] 21
#
# [[8]]$panel_region
# [1] "South, South East & Channel Is"
#
# [[8]]$is_macro_region
# [1] FALSE
#
#
# [[9]]
# [[9]]$panel_code
# [1] 24
#
# [[9]]$panel_region
# [1] "East of England"
#
# [[9]]$is_macro_region
# [1] FALSE
#
#
# [[10]]
# [[10]]$panel_code
# [1] 27
#
# [[10]]$panel_region
# [1] "South West"
#
# [[10]]$is_macro_region
# [1] FALSE
#
#
# [[11]]
# [[11]]$panel_code
# [1] 30
#
# [[11]]$panel_region
# [1] "Ulster - ITV,C4,ITV Breakfast"
#
# [[11]]$is_macro_region
# [1] FALSE
#
#
# [[12]]
# [[12]]$panel_code
# [1] 33
#
# [[12]]$panel_region
# [1] "Border"
#
# [[12]]$is_macro_region
# [1] FALSE
#
#
# [[13]]
# [[13]]$panel_code
# [1] 37
#
# [[13]]$panel_region
# [1] "West"
#
# [[13]]$is_macro_region
# [1] FALSE
#
#
# [[14]]
# [[14]]$panel_code
# [1] 38
#
# [[14]]$panel_region
# [1] "Wales"
#
# [[14]]$is_macro_region
# [1] FALSE
#
#
# [[15]]
# [[15]]$panel_code
# [1] 39
#
# [[15]]$panel_region
# [1] "S4C - Total"
#
# [[15]]$is_macro_region
# [1] FALSE
#
#
# [[16]]
# [[16]]$panel_code
# [1] 40
#
# [[16]]$panel_region
# [1] "S4C - Indivs in non Welsh Sp H"
#
# [[16]]$is_macro_region
# [1] FALSE
#
#
# [[17]]
# [[17]]$panel_code
# [1] 41
#
# [[17]]$panel_region
# [1] "S4C - Welsh Speaking Indivs"
#
# [[17]]$is_macro_region
# [1] FALSE
#
#
# [[18]]
# [[18]]$panel_code
# [1] 48
#
# [[18]]$panel_region
# [1] "S4C - Indivs in Welsh Sp HH's"
#
# [[18]]$is_macro_region
# [1] FALSE
#
#
# [[19]]
# [[19]]$panel_code
# [1] 49
#
# [[19]]$panel_region
# [1] "S4C - Network"
#
# [[19]]$is_macro_region
# [1] TRUE
#
#
# [[20]]
# [[20]]$panel_code
# [1] 50
#
# [[20]]$panel_region
# [1] "BBC Network"
#
# [[20]]$is_macro_region
# [1] FALSE
#
#
# [[21]]
# [[21]]$panel_code
# [1] 51
#
# [[21]]$panel_region
# [1] "Online Network"
#
# [[21]]$is_macro_region
# [1] FALSE
#
#
# [[22]]
# [[22]]$panel_code
# [1] 58
#
# [[22]]$panel_region
# [1] "ITV Breakfast North,South,Mids"
#
# [[22]]$is_macro_region
# [1] TRUE
#
#
# [[23]]
# [[23]]$panel_code
# [1] 59
#
# [[23]]$panel_region
# [1] "ITV Breakfast England & Wales"
#
# [[23]]$is_macro_region
# [1] TRUE
#
#
# [[24]]
# [[24]]$panel_code
# [1] 61
#
# [[24]]$panel_region
# [1] "Mid-West Macro"
#
# [[24]]$is_macro_region
# [1] TRUE
#
#
# [[25]]
# [[25]]$panel_code
# [1] 62
#
# [[25]]$panel_region
# [1] "West Macro"
#
# [[25]]$is_macro_region
# [1] TRUE
#
#
# [[26]]
# [[26]]$panel_code
# [1] 63
#
# [[26]]$panel_region
# [1] "Yorkshire/North East Macro"
#
# [[26]]$is_macro_region
# [1] TRUE
#
#
# [[27]]
# [[27]]$panel_code
# [1] 67
#
# [[27]]$panel_region
# [1] "North West/Border Macro"
#
# [[27]]$is_macro_region
# [1] TRUE
#
#
# [[28]]
# [[28]]$panel_code
# [1] 68
#
# [[28]]$panel_region
# [1] "ITV,ITV Breakfast North Macro"
#
# [[28]]$is_macro_region
# [1] TRUE
#
#
# [[29]]
# [[29]]$panel_code
# [1] 69
#
# [[29]]$panel_region
# [1] "South East Macro"
#
# [[29]]$is_macro_region
# [1] TRUE
#
#
# [[30]]
# [[30]]$panel_code
# [1] 72
#
# [[30]]$panel_region
# [1] "Cable & DSAT Homes"
#
# [[30]]$is_macro_region
# [1] FALSE
#
#
# [[31]]
# [[31]]$panel_code
# [1] 74
#
# [[31]]$panel_region
# [1] "Channel 5 Ulster Macro"
#
# [[31]]$is_macro_region
# [1] TRUE
#
#
# [[32]]
# [[32]]$panel_code
# [1] 75
#
# [[32]]$panel_region
# [1] "Channel 5 London Macro"
#
# [[32]]$is_macro_region
# [1] TRUE
#
#
# [[33]]
# [[33]]$panel_code
# [1] 76
#
# [[33]]$panel_region
# [1] "Channel 5 North Macro"
#
# [[33]]$is_macro_region
# [1] TRUE
#
#
# [[34]]
# [[34]]$panel_code
# [1] 77
#
# [[34]]$panel_region
# [1] "Channel 5 Scotland Macro"
#
# [[34]]$is_macro_region
# [1] TRUE
#
#
# [[35]]
# [[35]]$panel_code
# [1] 79
#
# [[35]]$panel_region
# [1] "Channel 5 Part Network Macro"
#
# [[35]]$is_macro_region
# [1] TRUE
#
#
# [[36]]
# [[36]]$panel_code
# [1] 80
#
# [[36]]$panel_region
# [1] "C4 Network"
#
# [[36]]$is_macro_region
# [1] TRUE
#
#
# [[37]]
# [[37]]$panel_code
# [1] 82
#
# [[37]]$panel_region
# [1] "C4 South - ITV Breakfast South"
#
# [[37]]$is_macro_region
# [1] TRUE
#
#
# [[38]]
# [[38]]$panel_code
# [1] 84
#
# [[38]]$panel_region
# [1] "C4 North"
#
# [[38]]$is_macro_region
# [1] TRUE
#
#
# [[39]]
# [[39]]$panel_code
# [1] 85
#
# [[39]]$panel_region
# [1] "C4 Scotland"
#
# [[39]]$is_macro_region
# [1] TRUE
#
#
# [[40]]
# [[40]]$panel_code
# [1] 87
#
# [[40]]$panel_region
# [1] "C4 - ITV Breakfast GB"
#
# [[40]]$is_macro_region
# [1] TRUE
#
#
# [[41]]
# [[41]]$panel_code
# [1] 88
#
# [[41]]$panel_region
# [1] "C4 England Macro"
#
# [[41]]$is_macro_region
# [1] TRUE
#
#
# [[42]]
# [[42]]$panel_code
# [1] 89
#
# [[42]]$panel_region
# [1] "C4 London/South/Mids Macro"
#
# [[42]]$is_macro_region
# [1] TRUE
#
#
# [[43]]
# [[43]]$panel_code
# [1] 90
#
# [[43]]$panel_region
# [1] "C4 London/South Macro"
#
# [[43]]$is_macro_region
# [1] TRUE
#
#
# [[44]]
# [[44]]$panel_code
# [1] 99
#
# [[44]]$panel_region
# [1] "ITV Network"
#
# [[44]]$is_macro_region
# [1] FALSE
#
#
# [[45]]
# [[45]]$panel_code
# [1] 100
#
# [[45]]$panel_region
# [1] "S4C Panel Boost Home"
#
# [[45]]$is_macro_region
# [1] FALSE
#
#
# [[46]]
# [[46]]$panel_code
# [1] 107
#
# [[46]]$panel_region
# [1] "Welsh Spk Ind In WSH - Northx"
#
# [[46]]$is_macro_region
# [1] FALSE
#
#
# [[47]]
# [[47]]$panel_code
# [1] 108
#
# [[47]]$panel_region
# [1] "Welsh Spk Ind In WSH - Westx"
#
# [[47]]$is_macro_region
# [1] FALSE
#
#
# [[48]]
# [[48]]$panel_code
# [1] 109
#
# [[48]]$panel_region
# [1] "Welsh Spk Ind in WSH - Southx"
#
# [[48]]$is_macro_region
# [1] FALSE
#
#
# [[49]]
# [[49]]$panel_code
# [1] 503
#
# [[49]]$panel_region
# [1] "BBC East Region"
#
# [[49]]$is_macro_region
# [1] FALSE
#
#
# [[50]]
# [[50]]$panel_code
# [1] 504
#
# [[50]]$panel_region
# [1] "BBC West Region"
#
# [[50]]$is_macro_region
# [1] FALSE
#
#
# [[51]]
# [[51]]$panel_code
# [1] 505
#
# [[51]]$panel_region
# [1] "BBC South West Region"
#
# [[51]]$is_macro_region
# [1] FALSE
#
#
# [[52]]
# [[52]]$panel_code
# [1] 506
#
# [[52]]$panel_region
# [1] "BBC South Region"
#
# [[52]]$is_macro_region
# [1] FALSE
#
#
# [[53]]
# [[53]]$panel_code
# [1] 507
#
# [[53]]$panel_region
# [1] "BBC Yorkshire & Lincolnshire"
#
# [[53]]$is_macro_region
# [1] FALSE
#
#
# [[54]]
# [[54]]$panel_code
# [1] 508
#
# [[54]]$panel_region
# [1] "BBC North East & Cumbria"
#
# [[54]]$is_macro_region
# [1] FALSE
#
#
# [[55]]
# [[55]]$panel_code
# [1] 509
#
# [[55]]$panel_region
# [1] "BBC North West Region"
#
# [[55]]$is_macro_region
# [1] FALSE
#
#
# [[56]]
# [[56]]$panel_code
# [1] 510
#
# [[56]]$panel_region
# [1] "BBC Scotland Region"
#
# [[56]]$is_macro_region
# [1] FALSE
#
#
# [[57]]
# [[57]]$panel_code
# [1] 511
#
# [[57]]$panel_region
# [1] "BBC Ulster Region"
#
# [[57]]$is_macro_region
# [1] FALSE
#
#
# [[58]]
# [[58]]$panel_code
# [1] 512
#
# [[58]]$panel_region
# [1] "BBC Wales Region"
#
# [[58]]$is_macro_region
# [1] FALSE
#
#
# [[59]]
# [[59]]$panel_code
# [1] 513
#
# [[59]]$panel_region
# [1] "BBC Midlands West"
#
# [[59]]$is_macro_region
# [1] FALSE
#
#
# [[60]]
# [[60]]$panel_code
# [1] 514
#
# [[60]]$panel_region
# [1] "BBC Midlands East"
#
# [[60]]$is_macro_region
# [1] FALSE
#
#
# [[61]]
# [[61]]$panel_code
# [1] 515
#
# [[61]]$panel_region
# [1] "BBC London"
#
# [[61]]$is_macro_region
# [1] FALSE
#
#
# [[62]]
# [[62]]$panel_code
# [1] 516
#
# [[62]]$panel_region
# [1] "BBC South East"
#
# [[62]]$is_macro_region
# [1] FALSE
#
#
# [[63]]
# [[63]]$panel_code
# [1] 670
#
# [[63]]$panel_region
# [1] "Broadband Network"
#
# [[63]]$is_macro_region
# [1] FALSE
#
#
# [[64]]
# [[64]]$panel_code
# [1] 750
#
# [[64]]$panel_region
# [1] "TV and/or online homes"
#
# [[64]]$is_macro_region
# [1] FALSE
#
#
# [[65]]
# [[65]]$panel_code
# [1] 751
#
# [[65]]$panel_region
# [1] "Online Multiple Screen Network"
#
# [[65]]$is_macro_region
# [1] FALSE
#
#
# [[66]]
# [[66]]$panel_code
# [1] 912
#
# [[66]]$panel_region
# [1] "Network Factoring - North East"
#
# [[66]]$is_macro_region
# [1] FALSE
#
#
# [[67]]
# [[67]]$panel_code
# [1] 927
#
# [[67]]$panel_region
# [1] "Network Factoring - SouthWest"
#
# [[67]]$is_macro_region
# [1] FALSE
#
#
# [[68]]
# [[68]]$panel_code
# [1] 930
#
# [[68]]$panel_region
# [1] "Network Factoring - Ulster"
#
# [[68]]$is_macro_region
# [1] FALSE
#
#
# [[69]]
# [[69]]$panel_code
# [1] 933
#
# [[69]]$panel_region
# [1] "Network Factoring - Border"
#
# [[69]]$is_macro_region
# [1] FALSE
#
#
# [[70]]
# [[70]]$panel_code
# [1] 937
#
# [[70]]$panel_region
# [1] "Network Factoring - HTV West"
#
# [[70]]$is_macro_region
# [1] FALSE
#
#
# [[71]]
# [[71]]$panel_code
# [1] 941
#
# [[71]]$panel_region
# [1] "Network - Wales"
#
# [[71]]$is_macro_region
# [1] FALSE

# %% [markdown]
# ## Connecting to the API with baRb
#
# baRb handles the authentication and connection to the API for you. First load the baRb package into memory.

# %%
library(baRb)

# %% [markdown]
# To use baRb to connect to Barb API we need to store the credentials environment variables. This can be done using the following code:

# %%
Sys.setenv(BARB_API_USERNAME = creds$email)
Sys.setenv(BARB_API_PASSWORD = creds$password)

# %% [markdown]
# Now we can use one of baRb's predefined functions to query an endpoint. Here we get a list of the Barb panels.

# %%
barb_get_panels()
# Out:
#     panel_code panel_region                   is_macro_region
# 1   1          London - ITV,C4,ITV Breakfast  FALSE
# 2   4          Midlands -ITV,C4,ITV Breakfast FALSE
# 3   7          North West                     FALSE
# 4   11         Yorkshire                      FALSE
# 5   12         North East                     FALSE
# 6   17         Scotland - ITV,ITV Breakfast   FALSE
# 7   18         Wales & West Macro             TRUE
# 8   21         South, South East & Channel Is FALSE
# 9   24         East of England                FALSE
# 10  27         South West                     FALSE
# 11  30         Ulster - ITV,C4,ITV Breakfast  FALSE
# 12  33         Border                         FALSE
# 13  37         West                           FALSE
# 14  38         Wales                          FALSE
# 15  39         S4C - Total                    FALSE
# 16  40         S4C - Indivs in non Welsh Sp H FALSE
# 17  41         S4C - Welsh Speaking Indivs    FALSE
# 18  48         S4C - Indivs in Welsh Sp HH's  FALSE
# 19  49         S4C - Network                  TRUE
# 20  50         BBC Network                    FALSE
# 21  51         Online Network                 FALSE
# 22  58         ITV Breakfast North,South,Mids TRUE
# 23  59         ITV Breakfast England & Wales  TRUE
# 24  61         Mid-West Macro                 TRUE
# 25  62         West Macro                     TRUE
# 26  63         Yorkshire/North East Macro     TRUE
# 27  67         North West/Border Macro        TRUE
# 28  68         ITV,ITV Breakfast North Macro  TRUE
# 29  69         South East Macro               TRUE
# 30  72         Cable & DSAT Homes             FALSE
# ... ...        ...                            ...
# 42  89         C4 London/South/Mids Macro     TRUE
# 43  90         C4 London/South Macro          TRUE
# 44  99         ITV Network                    FALSE
# 45  100        S4C Panel Boost Home           FALSE
# 46  107        Welsh Spk Ind In WSH - Northx  FALSE
# 47  108        Welsh Spk Ind In WSH - Westx   FALSE
# 48  109        Welsh Spk Ind in WSH - Southx  FALSE
# 49  503        BBC East Region                FALSE
# 50  504        BBC West Region                FALSE
# 51  505        BBC South West Region          FALSE
# 52  506        BBC South Region               FALSE
# 53  507        BBC Yorkshire & Lincolnshire   FALSE
# 54  508        BBC North East & Cumbria       FALSE
# 55  509        BBC North West Region          FALSE
# 56  510        BBC Scotland Region            FALSE
# 57  511        BBC Ulster Region              FALSE
# 58  512        BBC Wales Region               FALSE
# 59  513        BBC Midlands West              FALSE
# 60  514        BBC Midlands East              FALSE
# 61  515        BBC London                     FALSE
# 62  516        BBC South East                 FALSE
# 63  670        Broadband Network              FALSE
# 64  750        TV and/or online homes         FALSE
# 65  751        Online Multiple Screen Network FALSE
# 66  912        Network Factoring - North East FALSE
# 67  927        Network Factoring - SouthWest  FALSE
# 68  930        Network Factoring - Ulster     FALSE
# 69  933        Network Factoring - Border     FALSE
# 70  937        Network Factoring - HTV West   FALSE
# 71  941        Network - Wales                FALSE
